# %%
import csv
import datetime
import os
import random

import numpy as np
from keras.callbacks import ModelCheckpoint
from keras.layers import Activation
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dense
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential, Model
from keras.preprocessing import image
from keras.utils import to_categorical
from keras.applications.resnet50 import ResNet50
from keras.applications import VGG16
from keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from common import *

# %%
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

def display_images(image_paths):
    html_content = "<div width='100%'>"
    for image_path in image_paths:
        html_content += '<div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">\
         {image_path}:\
         <img src="{image_path}" style="display:inline-block;"> </div>'.format(image_path=image_path)
    html_content += '</div>'
    display(HTML(html_content))

# %%
print(".. setting base configuration ..")

random.seed(34283428)
base_dir_path = '.'
best_model_filepath = '{}/saved-models/model1.hdf5'.format(base_dir_path)
# Out:
# .. setting base configuration ..

# %%
print(".. setting model parameters ..")

training_epochs = 100
# Out:
# .. setting model parameters ..

# %%
print(".. loading & splitting data ..")
section_start_time = datetime.datetime.utcnow()

image_to_label = {}
images_list = []
label_list = []
with open('{base_dir_path}/data-labels/images.csv'.format(base_dir_path=base_dir_path),
          newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        image_name = row['IMAGE FILENAME'].strip()
        is_positive = 1 if row['IS POSITIVE'] else 0
        if image_name:
            image_path = '{base_dir_path}/data-images/{image_name}'.format(base_dir_path=base_dir_path,
                                                                           image_name=image_name)
            image_to_label[image_path] = is_positive
            images_list.append(image_path)
            label_list.append(is_positive)

label_list_categorical = to_categorical(label_list)

X_train, X_test, y_train, y_test = train_test_split(np.array(images_list),
                                                    np.array(label_list_categorical),
                                                    test_size=0.20,
                                                    random_state=42)

X_train, X_validate, y_train, y_validate = train_test_split(X_train,
                                                            y_train,
                                                            test_size=0.20,
                                                            random_state=42)

train_tensors = paths_to_tensor(X_train).astype('float32')
test_tensors = paths_to_tensor(X_test).astype('float32')
valid_tensors = paths_to_tensor(X_validate).astype('float32')

duration_loading = (datetime.datetime.utcnow() - section_start_time).total_seconds()
# Out:
#   2%|▏         | 16/896 [00:00<00:05, 159.34it/s]
# .. loading & splitting data ..
# 100%|██████████| 896/896 [00:04<00:00, 179.87it/s]
# 100%|██████████| 280/280 [00:01<00:00, 197.29it/s]
# 100%|██████████| 224/224 [00:01<00:00, 182.15it/s]

# %%
# external_model = InceptionV3(weights='imagenet', include_top=False)
# external_model = ResNet50(weights='imagenet', include_top=False)
external_model = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))

# %%
print(".. constructing the transfer model ..")

for layer in external_model.layers:
    layer.trainable = False

temp = Conv2D(filters=128, kernel_size=2, padding='same')(external_model.layers[-13].output)

temp = BatchNormalization()(temp)
temp = Activation('relu')(temp)
temp = MaxPooling2D(pool_size=(2, 2))(temp)
temp = GlobalAveragePooling2D()(temp)
predictions = Dense(2, activation='softmax')(temp)

model = Model(input=external_model.input, output=predictions)

model.summary()    

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# .. constructing the transfer model ..
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 128)       65664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# global_average_pooling2d_26  (None, 128)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 326,594
# Trainable params: 66,178
# Non-trainable params: 260,416
# _________________________________________________________________
# /Users/pmartin/ml/venv/udacity-capstone/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
print(".. training the model ..")
section_start_time = datetime.datetime.utcnow()

checkpointer = ModelCheckpoint(filepath=best_model_filepath,
                               verbose=1,
                               save_best_only=True)

model.fit(train_tensors, y_train,
          validation_data=(valid_tensors, y_validate),
          epochs=training_epochs,
          batch_size=20,
          callbacks=[checkpointer],
          verbose=1)

duration_training = (datetime.datetime.utcnow() - section_start_time).total_seconds()
# Out:
# .. training the model ..
# Train on 896 samples, validate on 224 samples
# Epoch 1/100
# 896/896 [==============================] - 335s 374ms/step - loss: 0.3581 - acc: 0.8337 - val_loss: 0.5694 - val_acc: 0.7768
#
# Epoch 00001: val_loss improved from inf to 0.56935, saving model to ./saved-models/model1.hdf5
# Epoch 2/100
# 896/896 [==============================] - 300s 334ms/step - loss: 0.2813 - acc: 0.8650 - val_loss: 0.1833 - val_acc: 0.9286
#
# Epoch 00002: val_loss improved from 0.56935 to 0.18326, saving model to ./saved-models/model1.hdf5
# Epoch 3/100
# 896/896 [==============================] - 351s 392ms/step - loss: 0.2554 - acc: 0.8862 - val_loss: 0.1653 - val_acc: 0.9330
#
# Epoch 00003: val_loss improved from 0.18326 to 0.16532, saving model to ./saved-models/model1.hdf5
# Epoch 4/100
# 896/896 [==============================] - 336s 375ms/step - loss: 0.2536 - acc: 0.8828 - val_loss: 0.2214 - val_acc: 0.9062
#
# Epoch 00004: val_loss did not improve from 0.16532
# Epoch 5/100
# 896/896 [==============================] - 365s 407ms/step - loss: 0.2334 - acc: 0.8962 - val_loss: 0.1532 - val_acc: 0.9286
#
# Epoch 00005: val_loss improved from 0.16532 to 0.15319, saving model to ./saved-models/model1.hdf5
# Epoch 6/100
# 896/896 [==============================] - 372s 415ms/step - loss: 0.2202 - acc: 0.9062 - val_loss: 0.2623 - val_acc: 0.9241
#
# Epoch 00006: val_loss did not improve from 0.15319
# Epoch 7/100
# 896/896 [==============================] - 395s 441ms/step - loss: 0.2179 - acc: 0.9074 - val_loss: 0.4173 - val_acc: 0.8125
#
# Epoch 00007: val_loss did not improve from 0.15319
# Epoch 8/100
# 896/896 [==============================] - 323s 361ms/step - loss: 0.2148 - acc: 0.9074 - val_loss: 0.1450 - val_acc: 0.9464
#
# Epoch 00008: val_loss improved from 0.15319 to 0.14498, saving model to ./saved-models/model1.hdf5
# Epoch 9/100
# 896/896 [==============================] - 290s 323ms/step - loss: 0.2080 - acc: 0.9062 - val_loss: 0.1246 - val_acc: 0.9420
#
# Epoch 00009: val_loss improved from 0.14498 to 0.12462, saving model to ./saved-models/model1.hdf5
# Epoch 10/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1985 - acc: 0.9163 - val_loss: 0.2056 - val_acc: 0.8973
#
# Epoch 00010: val_loss did not improve from 0.12462
# Epoch 11/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1823 - acc: 0.9230 - val_loss: 0.3673 - val_acc: 0.8616
#
# Epoch 00011: val_loss did not improve from 0.12462
# Epoch 12/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1971 - acc: 0.9185 - val_loss: 0.2689 - val_acc: 0.9018
#
# Epoch 00012: val_loss did not improve from 0.12462
# Epoch 13/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1961 - acc: 0.9141 - val_loss: 0.1439 - val_acc: 0.9420
#
# Epoch 00013: val_loss did not improve from 0.12462
# Epoch 14/100
# 896/896 [==============================] - 285s 319ms/step - loss: 0.1788 - acc: 0.9241 - val_loss: 0.1618 - val_acc: 0.9241
#
# Epoch 00014: val_loss did not improve from 0.12462
# Epoch 15/100
# 896/896 [==============================] - 285s 319ms/step - loss: 0.1921 - acc: 0.9241 - val_loss: 0.3393 - val_acc: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.12462
# Epoch 16/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1746 - acc: 0.9252 - val_loss: 0.3087 - val_acc: 0.8571
#
# Epoch 00016: val_loss did not improve from 0.12462
# Epoch 17/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1654 - acc: 0.9286 - val_loss: 0.1146 - val_acc: 0.9554
#
# Epoch 00017: val_loss improved from 0.12462 to 0.11458, saving model to ./saved-models/model1.hdf5
# Epoch 18/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1696 - acc: 0.9342 - val_loss: 0.1462 - val_acc: 0.9375
#
# Epoch 00018: val_loss did not improve from 0.11458
# Epoch 19/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1781 - acc: 0.9230 - val_loss: 0.2306 - val_acc: 0.9107
#
# Epoch 00019: val_loss did not improve from 0.11458
# Epoch 20/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1848 - acc: 0.9163 - val_loss: 0.4404 - val_acc: 0.8304
#
# Epoch 00020: val_loss did not improve from 0.11458
# Epoch 21/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1707 - acc: 0.9330 - val_loss: 0.5256 - val_acc: 0.7679
#
# Epoch 00021: val_loss did not improve from 0.11458
# Epoch 22/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1595 - acc: 0.9342 - val_loss: 0.7285 - val_acc: 0.7054
#
# Epoch 00022: val_loss did not improve from 0.11458
# Epoch 23/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1635 - acc: 0.9386 - val_loss: 0.1467 - val_acc: 0.9286
#
# Epoch 00023: val_loss did not improve from 0.11458
# Epoch 24/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1533 - acc: 0.9353 - val_loss: 0.1162 - val_acc: 0.9509
#
# Epoch 00024: val_loss did not improve from 0.11458
# Epoch 25/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1563 - acc: 0.9397 - val_loss: 0.2535 - val_acc: 0.8750
#
# Epoch 00025: val_loss did not improve from 0.11458
# Epoch 26/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1558 - acc: 0.9297 - val_loss: 0.6923 - val_acc: 0.7411
#
# Epoch 00026: val_loss did not improve from 0.11458
# Epoch 27/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1693 - acc: 0.9308 - val_loss: 0.1207 - val_acc: 0.9598
#
# Epoch 00027: val_loss did not improve from 0.11458
# Epoch 28/100
# 896/896 [==============================] - 288s 321ms/step - loss: 0.1465 - acc: 0.9420 - val_loss: 0.1073 - val_acc: 0.9464
#
# Epoch 00028: val_loss improved from 0.11458 to 0.10726, saving model to ./saved-models/model1.hdf5
# Epoch 29/100
# 896/896 [==============================] - 287s 321ms/step - loss: 0.1528 - acc: 0.9353 - val_loss: 0.1329 - val_acc: 0.9509
#
# Epoch 00029: val_loss did not improve from 0.10726
# Epoch 30/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1501 - acc: 0.9386 - val_loss: 0.3909 - val_acc: 0.8304
#
# Epoch 00030: val_loss did not improve from 0.10726
# Epoch 31/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1371 - acc: 0.9475 - val_loss: 0.1204 - val_acc: 0.9375
#
# Epoch 00031: val_loss did not improve from 0.10726
# Epoch 32/100
# 896/896 [==============================] - 288s 322ms/step - loss: 0.1455 - acc: 0.9442 - val_loss: 0.1604 - val_acc: 0.9241
#
# Epoch 00032: val_loss did not improve from 0.10726
# Epoch 33/100
# 896/896 [==============================] - 291s 325ms/step - loss: 0.1357 - acc: 0.9453 - val_loss: 0.2160 - val_acc: 0.8973
#
# Epoch 00033: val_loss did not improve from 0.10726
# Epoch 34/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1653 - acc: 0.9286 - val_loss: 0.2196 - val_acc: 0.8884
#
# Epoch 00034: val_loss did not improve from 0.10726
# Epoch 35/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1310 - acc: 0.9453 - val_loss: 0.1074 - val_acc: 0.9554
#
# Epoch 00035: val_loss did not improve from 0.10726
# Epoch 36/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1460 - acc: 0.9353 - val_loss: 0.1020 - val_acc: 0.9509
#
# Epoch 00036: val_loss improved from 0.10726 to 0.10200, saving model to ./saved-models/model1.hdf5
# Epoch 37/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1340 - acc: 0.9475 - val_loss: 0.2885 - val_acc: 0.8884
#
# Epoch 00037: val_loss did not improve from 0.10200
# Epoch 38/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1607 - acc: 0.9375 - val_loss: 0.2493 - val_acc: 0.8973
#
# Epoch 00038: val_loss did not improve from 0.10200
# Epoch 39/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1300 - acc: 0.9453 - val_loss: 0.1060 - val_acc: 0.9554
#
# Epoch 00039: val_loss did not improve from 0.10200
# Epoch 40/100
# 896/896 [==============================] - 286s 320ms/step - loss: 0.1242 - acc: 0.9565 - val_loss: 1.0243 - val_acc: 0.7946
#
# Epoch 00040: val_loss did not improve from 0.10200
# Epoch 41/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1475 - acc: 0.9397 - val_loss: 0.2327 - val_acc: 0.8750
# Epoch 00041: val_loss did not improve from 0.10200
# Epoch 42/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1365 - acc: 0.9408 - val_loss: 0.2693 - val_acc: 0.8929
#
# Epoch 00042: val_loss did not improve from 0.10200
# Epoch 43/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1301 - acc: 0.9464 - val_loss: 0.4049 - val_acc: 0.8348
#
# Epoch 00043: val_loss did not improve from 0.10200
# Epoch 44/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1305 - acc: 0.9498 - val_loss: 0.8876 - val_acc: 0.6920
#
# Epoch 00044: val_loss did not improve from 0.10200
# Epoch 45/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1348 - acc: 0.9386 - val_loss: 0.1155 - val_acc: 0.9420
#
# Epoch 00045: val_loss did not improve from 0.10200
# Epoch 46/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1181 - acc: 0.9565 - val_loss: 0.2122 - val_acc: 0.9152
#
# Epoch 00046: val_loss did not improve from 0.10200
# Epoch 47/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1279 - acc: 0.9498 - val_loss: 0.3876 - val_acc: 0.8527
#
# Epoch 00047: val_loss did not improve from 0.10200
# Epoch 48/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1272 - acc: 0.9464 - val_loss: 0.5809 - val_acc: 0.7902
#
# Epoch 00048: val_loss did not improve from 0.10200
# Epoch 49/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1304 - acc: 0.9498 - val_loss: 0.1051 - val_acc: 0.9598
#
# Epoch 00049: val_loss did not improve from 0.10200
# Epoch 50/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1170 - acc: 0.9554 - val_loss: 0.1127 - val_acc: 0.9554
#
# Epoch 00050: val_loss did not improve from 0.10200
# Epoch 51/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1138 - acc: 0.9576 - val_loss: 0.0989 - val_acc: 0.9598
#
# Epoch 00051: val_loss improved from 0.10200 to 0.09891, saving model to ./saved-models/model1.hdf5
# Epoch 52/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1225 - acc: 0.9520 - val_loss: 1.6629 - val_acc: 0.7946
#
# Epoch 00052: val_loss did not improve from 0.09891
# Epoch 53/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1140 - acc: 0.9587 - val_loss: 0.4267 - val_acc: 0.8214
#
# Epoch 00053: val_loss did not improve from 0.09891
# Epoch 54/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1197 - acc: 0.9587 - val_loss: 0.6741 - val_acc: 0.7366
#
# Epoch 00054: val_loss did not improve from 0.09891
# Epoch 55/100
# 896/896 [==============================] - 284s 317ms/step - loss: 0.1111 - acc: 0.9542 - val_loss: 0.1023 - val_acc: 0.9554
#
# Epoch 00055: val_loss did not improve from 0.09891
# Epoch 56/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1201 - acc: 0.9498 - val_loss: 0.5509 - val_acc: 0.7991
#
# Epoch 00056: val_loss did not improve from 0.09891
# Epoch 57/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1049 - acc: 0.9665 - val_loss: 0.5901 - val_acc: 0.7768
#
# Epoch 00057: val_loss did not improve from 0.09891
# Epoch 58/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1097 - acc: 0.9576 - val_loss: 0.6927 - val_acc: 0.8080
#
# Epoch 00058: val_loss did not improve from 0.09891
# Epoch 59/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1193 - acc: 0.9442 - val_loss: 0.9363 - val_acc: 0.7009
#
# Epoch 00059: val_loss did not improve from 0.09891
# Epoch 60/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1187 - acc: 0.9520 - val_loss: 0.0978 - val_acc: 0.9554
#
# Epoch 00060: val_loss improved from 0.09891 to 0.09778, saving model to ./saved-models/model1.hdf5
# Epoch 61/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1091 - acc: 0.9554 - val_loss: 0.8340 - val_acc: 0.7946
#
# Epoch 00061: val_loss did not improve from 0.09778
# Epoch 62/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1128 - acc: 0.9643 - val_loss: 0.5096 - val_acc: 0.8259
#
# Epoch 00062: val_loss did not improve from 0.09778
# Epoch 63/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1033 - acc: 0.9632 - val_loss: 0.4731 - val_acc: 0.8348
#
# Epoch 00063: val_loss did not improve from 0.09778
# Epoch 64/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1210 - acc: 0.9509 - val_loss: 0.1987 - val_acc: 0.9107
#
# Epoch 00064: val_loss did not improve from 0.09778
# Epoch 65/100
# 896/896 [==============================] - 290s 324ms/step - loss: 0.1014 - acc: 0.9609 - val_loss: 0.1739 - val_acc: 0.9196
#
# Epoch 00065: val_loss did not improve from 0.09778
# Epoch 66/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1057 - acc: 0.9621 - val_loss: 0.4235 - val_acc: 0.8438
#
# Epoch 00066: val_loss did not improve from 0.09778
# Epoch 67/100
# 896/896 [==============================] - 288s 321ms/step - loss: 0.1034 - acc: 0.9587 - val_loss: 0.1388 - val_acc: 0.9420
#
# Epoch 00067: val_loss did not improve from 0.09778
# Epoch 68/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1118 - acc: 0.9598 - val_loss: 0.3873 - val_acc: 0.8438
#
# Epoch 00068: val_loss did not improve from 0.09778
# Epoch 69/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1011 - acc: 0.9565 - val_loss: 0.2617 - val_acc: 0.8973
#
# Epoch 00069: val_loss did not improve from 0.09778
# Epoch 70/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1061 - acc: 0.9554 - val_loss: 0.1463 - val_acc: 0.9375
#
# Epoch 00070: val_loss did not improve from 0.09778
# Epoch 71/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0971 - acc: 0.9665 - val_loss: 0.4729 - val_acc: 0.8438
#
# Epoch 00071: val_loss did not improve from 0.09778
# Epoch 72/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1040 - acc: 0.9632 - val_loss: 1.5878 - val_acc: 0.5714
#
# Epoch 00072: val_loss did not improve from 0.09778
# Epoch 73/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.1235 - acc: 0.9542 - val_loss: 0.5281 - val_acc: 0.8304
#
# Epoch 00073: val_loss did not improve from 0.09778
# Epoch 74/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0828 - acc: 0.9710 - val_loss: 0.8714 - val_acc: 0.7054
#
# Epoch 00074: val_loss did not improve from 0.09778
# Epoch 75/100
# 896/896 [==============================] - 287s 321ms/step - loss: 0.0906 - acc: 0.9699 - val_loss: 0.1017 - val_acc: 0.9598
#
# Epoch 00075: val_loss did not improve from 0.09778
# Epoch 76/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1027 - acc: 0.9654 - val_loss: 0.1064 - val_acc: 0.9420
#
# Epoch 00076: val_loss did not improve from 0.09778
# Epoch 77/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0984 - acc: 0.9643 - val_loss: 0.1337 - val_acc: 0.9509
#
# Epoch 00077: val_loss did not improve from 0.09778
# Epoch 78/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.1016 - acc: 0.9609 - val_loss: 0.9041 - val_acc: 0.7946
#
# Epoch 00078: val_loss did not improve from 0.09778
# Epoch 79/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.0983 - acc: 0.9699 - val_loss: 0.0998 - val_acc: 0.9554
#
# Epoch 00079: val_loss did not improve from 0.09778
# Epoch 80/100
# 896/896 [==============================] - 286s 320ms/step - loss: 0.0932 - acc: 0.9643 - val_loss: 1.8514 - val_acc: 0.5223
#
# Epoch 00080: val_loss did not improve from 0.09778
# Epoch 81/100
# 896/896 [==============================] - 285s 319ms/step - loss: 0.0983 - acc: 0.9609 - val_loss: 0.2490 - val_acc: 0.9018
#
# Epoch 00081: val_loss did not improve from 0.09778
# Epoch 82/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0925 - acc: 0.9665 - val_loss: 0.1420 - val_acc: 0.9464
#
# Epoch 00082: val_loss did not improve from 0.09778
# Epoch 83/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0965 - acc: 0.9643 - val_loss: 0.4413 - val_acc: 0.8348
#
# Epoch 00083: val_loss did not improve from 0.09778
# Epoch 84/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0984 - acc: 0.9665 - val_loss: 1.2646 - val_acc: 0.7946
#
# Epoch 00084: val_loss did not improve from 0.09778
# Epoch 85/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0823 - acc: 0.9732 - val_loss: 0.1701 - val_acc: 0.9152
#
# Epoch 00085: val_loss did not improve from 0.09778
# Epoch 86/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0883 - acc: 0.9643 - val_loss: 0.1142 - val_acc: 0.9420
#
# Epoch 00086: val_loss did not improve from 0.09778
# Epoch 87/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0871 - acc: 0.9676 - val_loss: 0.7812 - val_acc: 0.8036
#
# Epoch 00087: val_loss did not improve from 0.09778
# Epoch 88/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0955 - acc: 0.9632 - val_loss: 0.1540 - val_acc: 0.9375
#
# Epoch 00088: val_loss did not improve from 0.09778
# Epoch 89/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.1006 - acc: 0.9609 - val_loss: 3.2083 - val_acc: 0.3973
#
# Epoch 00089: val_loss did not improve from 0.09778
# Epoch 90/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0938 - acc: 0.9643 - val_loss: 0.2845 - val_acc: 0.8795
#
# Epoch 00090: val_loss did not improve from 0.09778
# Epoch 91/100
# 896/896 [==============================] - 285s 319ms/step - loss: 0.0911 - acc: 0.9665 - val_loss: 0.2567 - val_acc: 0.8929
#
# Epoch 00091: val_loss did not improve from 0.09778
# Epoch 92/100
# 896/896 [==============================] - 289s 322ms/step - loss: 0.0909 - acc: 0.9632 - val_loss: 0.4189 - val_acc: 0.8438
#
# Epoch 00092: val_loss did not improve from 0.09778
# Epoch 93/100
# 896/896 [==============================] - 287s 320ms/step - loss: 0.0928 - acc: 0.9654 - val_loss: 0.2820 - val_acc: 0.8795
#
# Epoch 00093: val_loss did not improve from 0.09778
# Epoch 94/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0871 - acc: 0.9687 - val_loss: 2.1176 - val_acc: 0.7946
#
# Epoch 00094: val_loss did not improve from 0.09778
# Epoch 95/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0854 - acc: 0.9643 - val_loss: 0.1973 - val_acc: 0.9062
#
# Epoch 00095: val_loss did not improve from 0.09778
# Epoch 96/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0911 - acc: 0.9654 - val_loss: 0.1584 - val_acc: 0.9330
#
# Epoch 00096: val_loss did not improve from 0.09778
# Epoch 97/100
# 896/896 [==============================] - 286s 320ms/step - loss: 0.0778 - acc: 0.9743 - val_loss: 0.1980 - val_acc: 0.9152
#
# Epoch 00097: val_loss did not improve from 0.09778
# Epoch 98/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0791 - acc: 0.9754 - val_loss: 0.1165 - val_acc: 0.9464
#
# Epoch 00098: val_loss did not improve from 0.09778
# Epoch 99/100
# 896/896 [==============================] - 286s 319ms/step - loss: 0.0892 - acc: 0.9654 - val_loss: 0.1307 - val_acc: 0.9420
#
# Epoch 00099: val_loss did not improve from 0.09778
# Epoch 100/100
# 896/896 [==============================] - 285s 318ms/step - loss: 0.0744 - acc: 0.9777 - val_loss: 0.7020 - val_acc: 0.7723
#
# Epoch 00100: val_loss did not improve from 0.09778

# %%
print(".. loading best weights ..")

model.load_weights(best_model_filepath)

print(".. testing the model ..")
section_start_time = datetime.datetime.utcnow()

# tmp_predictions = [model.predict(np.expand_dims(tensor, axis=0)) for tensor in test_tensors]
test_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in tqdm(test_tensors)]

duration_testing = (datetime.datetime.utcnow() - section_start_time).total_seconds()
# Out:
# .. loading best weights ..
#   0%|          | 0/280 [00:00<?, ?it/s]
# .. testing the model ..
# 100%|██████████| 280/280 [01:04<00:00,  4.53it/s]

# %%
print(".. analyzing results ..")

true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
all_positives = 0
all_test = len(X_test)

false_positive_images = []
false_negative_images = []

for n, test_image in enumerate(tqdm(X_test)):
    prediction_label = True if test_predictions[n] else False
    truth_label = True if y_test[n][1] else False
    correct_prediction = prediction_label == truth_label

#     print("{indicator} {truth_icon} {test_image} (is {truth} predicted {prediction})".format(
#         indicator=' ' if correct_prediction else 'X',
#         truth_icon='|' if truth_label else '=',
#         test_image=test_image,
#         truth=truth_label,
#         prediction=prediction_label,
#     ))

    if truth_label:
        all_positives += 1

    if prediction_label:
        if truth_label:
            true_positives += 1
        else:
            false_positives += 1
            false_positive_images.append(test_image)
    else:
        if truth_label:
            false_negatives += 1
            false_negative_images.append(test_image)
        else:
            true_negatives += 1
# Out:
# 100%|██████████| 280/280 [00:00<00:00, 94080.36it/s]
# .. analyzing results ..

# %%
print("________________________________________________________")
print("SUMMARY:\n")
print("loading duration: {0:.1f} seconds".format(duration_loading))
print("training duration: {0:.1f} seconds".format(duration_training))
print("testing duration: {0:.1f} seconds".format(duration_testing))

print("all: ", all_test)
print("all_positives: ", all_positives)
print("true_positives: ", true_positives)
print("true_negatives: ", true_negatives)
print("false_positives: ", false_positives)
print("false_negatives: ", false_negatives)

print("RECALL: {0:.2f}%".format(100 * true_positives / all_positives))
print("ACCURACY: {0:.2f}%".format(100 * (true_positives + true_negatives) / all_test))
# Out:
# ________________________________________________________
# SUMMARY:
#
# loading duration: 9.2 seconds
# training duration: 29077.9 seconds
# testing duration: 64.8 seconds
# all:  280
# all_positives:  56
# true_positives:  51
# true_negatives:  218
# false_positives:  6
# false_negatives:  5
# RECALL: 91.07%
# ACCURACY: 96.07%

# %% [markdown]
# ## False Positives (first 20):

# %%
display_images(false_positive_images[:20])
# Out:
# <div width='100%'><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831138807001-1266.jpg:         <img src="./data-images/5831138807001-1266.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831139883001-1904.jpg:         <img src="./data-images/5831139883001-1904.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5833084561001-1873.jpg:         <img src="./data-images/5833084561001-1873.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831139883001-109.jpg:         <img src="./data-images/5831139883001-109.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5833090951001-461.jpg:         <img src="./data-images/5833090951001-461.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5833096735001-2172.jpg:         <img src="./data-images/5833096735001-2172.jpg" style="display:inline-block;"> </div></div>

# %% [markdown]
# ## False Negatives (first 20):

# %%
display_images(false_negative_images[:20])
# Out:
# <div width='100%'><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831139883001-1337.jpg:         <img src="./data-images/5831139883001-1337.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831138807001-1167.jpg:         <img src="./data-images/5831138807001-1167.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831138807001-1837.jpg:         <img src="./data-images/5831138807001-1837.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831135399001-905.jpg:         <img src="./data-images/5831135399001-905.jpg" style="display:inline-block;"> </div><div style="font-size: 10px; display:inline-block; width: 224px; border:1px solid black">         ./data-images/5831135399001-2241.jpg:         <img src="./data-images/5831135399001-2241.jpg" style="display:inline-block;"> </div></div>
